# %%
pip install -r ".devcontainer/requirements.txt"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/keboola/python-transformation.git (to revision 3678de500f2865d0e84f42c3ec8ce079186f5361) to /tmp/pip-install-_ogkyn8a/kbc-transformation_9e58cf2425ff45fc8f70e635122f4a84
#   Running command git clone --filter=blob:none --quiet https://github.com/keboola/python-transformation.git /tmp/pip-install-_ogkyn8a/kbc-transformation_9e58cf2425ff45fc8f70e635122f4a84
#   Running command git rev-parse -q --verify 'sha^3678de500f2865d0e84f42c3ec8ce079186f5361'
#   Running command git fetch -q https://github.com/keboola/python-transformation.git 3678de500f2865d0e84f42c3ec8ce079186f5361
#   Running command git checkout -q 3678de500f2865d0e84f42c3ec8ce079186f5361
#   Resolved https://github.com/keboola/python-transformation.git to commit 3678de500f2865d0e84f42c3ec8ce079186f5361
#   Preparing metadata (setup.py) ... done
# ...
